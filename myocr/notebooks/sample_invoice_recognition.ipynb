# %%
from pydantic import BaseModel, Field
from myocr.pipelines.structured_output_pipeline import StructuredOutputOCRPipeline


class InvoiceItem(BaseModel):
    name:str = Field(
        description="发票中的项目名称"
    )
    price:float = Field(
        description="项目单价"
    )
    number:str = Field(
        description="项目数量"
    )
    tax:str = Field(
        description="项目税额，请转为两位小数表示"
    )

class InvoiceModel(BaseModel):
    invoiceNumber:str = Field(
        description="发票号码，一般在发票的又上角"
    )
    invoiceDate:str = Field(
        description="发票日期，每张发票都有一个开票日期，一般在发票的右上角，请用这种格式展示 yyyy/MM/DD"
    )
    invoiceItems: list[InvoiceItem] = Field(
        description="发票中的项目列表，这是发票中的主要内容，一般包含项目的名称，单价，数量，总价，税率，税额等，注意：这个字段是数组类型"
    )
    totalAmount:float = Field(
        description="发票的总金额"
    )


pipeline = StructuredOutputOCRPipeline("cuda:0", InvoiceModel)
pipeline("../../tests/images/invoice.png")
# Out:
# 2025-04-09 15:50:53,839 - matplotlib - DEBUG - __init__ - wrapper - 342 - matplotlib data path: /home/robby/miniconda3/envs/myocr/lib/python3.11/site-packages/matplotlib/mpl-data
# 2025-04-09 15:50:53,843 - matplotlib - DEBUG - __init__ - wrapper - 342 - CONFIGDIR=/home/robby/.config/matplotlib
# 2025-04-09 15:50:53,847 - matplotlib - DEBUG - __init__ - <module> - 1557 - interactive is False
# 2025-04-09 15:50:53,847 - matplotlib - DEBUG - __init__ - <module> - 1558 - platform is linux
# 2025-04-09 15:50:53,867 - matplotlib - DEBUG - __init__ - wrapper - 342 - CACHEDIR=/home/robby/.cache/matplotlib
# 2025-04-09 15:50:53,868 - matplotlib.font_manager - DEBUG - font_manager - _load_fontmanager - 1635 - Using fontManager instance from /home/robby/.cache/matplotlib/fontlist-v390.json
# 2025-04-09 15:50:54,030 - myocr.modeling.model - INFO - model - load - 126 - Onnx model /home/robby/.MyOCR/models/dbnet++.onnx loaded to cuda:0,
#                     input output info: {'inputs': {'x': {'shape': ['p2o.DynamicDimension.0', 3, 'p2o.DynamicDimension.1', 'p2o.DynamicDimension.2'], 'type': 'tensor(float)'}}, 'outputs': {'sigmoid_0.tmp_0': {'shape': ['p2o.DynamicDimension.3', 1, 'p2o.DynamicDimension.4', 'p2o.DynamicDimension.5'], 'type': 'tensor(float)'}}}
# 2025-04-09 15:50:54,067 - myocr.modeling.model - INFO - model - load - 126 - Onnx model /home/robby/.MyOCR/models/rec.onnx loaded to cuda:0,
#                     input output info: {'inputs': {'x': {'shape': ['p2o.DynamicDimension.0', 3, 48, 'p2o.DynamicDimension.1'], 'type': 'tensor(float)'}}, 'outputs': {'softmax_11.tmp_0': {'shape': ['p2o.DynamicDimension.2', 'p2o.DynamicDimension.3', 6625], 'type': 'tensor(float)'}}}
# 2025-04-09 15:50:54,343 - myocr.predictors.text_detection_predictor - DEBUG - text_detection_predictor - convert_output - 85 - text detection output shape: (1056, 1568)
# 2025-04-09 15:50:54,567 - myocr.predictors.text_recognition_predictor - DEBUG - text_recognition_predictor - convert_output - 88 - text recognition output shape: (51, 137, 6625)
# 2025-04-09 15:50:54,636 - myocr.pipelines.structured_output_pipeline - DEBUG - structured_output_pipeline - __call__ - 46 - recognized texts is: [(text=发票）, confidence=0.00040936365257948637, bounding_box=(left=885, bottom=125, right=1024, top=56, score=0.8755382433622291))
# , (text=电子发, confidence=0.00040981877828016877, bounding_box=(left=521, bottom=123, right=682, top=58, score=0.8887948973740383))
# , (text=严统发著, confidence=0.00039548726635985076, bounding_box=(left=683, bottom=108, right=861, top=64, score=0.43799788377065085))
# , (text=, confidence=0.0004014992155134678, bounding_box=(left=830, bottom=112, right=888, top=74, score=0.7139545332502436))
# , (text=音, confidence=0.0004075212054885924, bounding_box=(left=790, bottom=115, right=848, top=87, score=0.6088384004659527))
# , (text=发票号码：24517000000216393366, confidence=0.0004092299204785377, bounding_box=(left=1162, bottom=114, right=1523, top=87, score=0.8445811400752314))
# , (text=旅客运输服务, confidence=0.00041017349576577544, bounding_box=(left=243, bottom=130, right=391, top=100, score=0.9379645352677781))
# , (text=州, confidence=0.00040773660293780267, bounding_box=(left=693, bottom=127, right=716, top=106, score=0.7340345462163289))
# , (text=咖, confidence=0.00040598533814772964, bounding_box=(left=862, bottom=127, right=888, top=107, score=0.697746460084562))
# , (text=国家税务总局, confidence=0.00040996362804435194, bounding_box=(left=731, bottom=148, right=847, top=109, score=0.7248885206306009))
# , (text=开票日期：2024年10月19日, confidence=0.00041008926928043365, bounding_box=(left=1161, bottom=159, right=1448, top=132, score=0.8337870823970539))
# , (text=司, confidence=0.0004022172070108354, bounding_box=(left=839, bottom=174, right=866, top=146, score=0.7119205463297512))
# , (text=四, confidence=0.000407859799452126, bounding_box=(left=713, bottom=172, right=735, top=148, score=0.7912848262172757))
# , (text=川, confidence=0.0004096296033822, bounding_box=(left=735, bottom=182, right=758, top=160, score=0.7831367289026578))
# , (text=务, confidence=0.0004090392030775547, bounding_box=(left=818, bottom=184, right=844, top=160, score=0.7439178495438068))
# , (text=省税, confidence=0.00041000088094733655, bounding_box=(left=762, bottom=189, right=819, top=163, score=0.782881618823324))
# , (text=1, confidence=0.00039894747897051275, bounding_box=(left=810, bottom=179, right=823, top=168, score=0.7052404930194218))
# , (text=, confidence=0.00037528277607634664, bounding_box=(left=790, bottom=381, right=828, top=227, score=0.7138049015923152))
# , (text=o, confidence=0.00037735956721007824, bounding_box=(left=36, bottom=377, right=71, top=228, score=0.7978249785861349))
# , (text=名称：北京邑邻科技有限公司, confidence=0.00041018589399755, bounding_box=(left=79, bottom=270, right=389, top=241, score=0.8433992134585773))
# , (text=名称：成都滴滴优行科技有限公司, confidence=0.0004101732047274709, bounding_box=(left=836, bottom=270, right=1194, top=241, score=0.8286933904921515))
# , (text=统一社会信用代码/纳税人识别号：91510100MA6B7L2R7L, confidence=0.0004095274198334664, bounding_box=(left=834, bottom=352, right=1495, top=323, score=0.7485454590197844))
# , (text=统一社会信用代码/纳税人识别号：91110105MA01Q7QUXU, confidence=0.0004092419985681772, bounding_box=(left=77, bottom=353, right=740, top=324, score=0.7606884741301113))
# , (text=单价, confidence=0.00040984779479913414, bounding_box=(left=538, bottom=422, right=610, top=384, score=0.8672588260806336))
# , (text=数量, confidence=0.00040964726940728724, bounding_box=(left=782, bottom=419, right=849, top=385, score=0.8792654913189503))
# , (text=金额, confidence=0.00040967980748973787, bounding_box=(left=1032, bottom=420, right=1102, top=386, score=0.9415918178797892))
# , (text=税率ç/征收率, confidence=0.00040845759212970734, bounding_box=(left=1193, bottom=419, right=1332, top=387, score=0.8943826571818677))
# , (text=项目名称, confidence=0.0004101831291336566, bounding_box=(left=194, bottom=416, right=299, top=388, score=0.8273995642024692))
# , (text=税额, confidence=0.00040995358722284436, bounding_box=(left=1471, bottom=419, right=1541, top=388, score=0.9166263459749472))
# , (text=42.04, confidence=0.0004072094743605703, bounding_box=(left=538, bottom=452, right=609, top=420, score=0.9202162409440064))
# , (text=42.04, confidence=0.0004086139961145818, bounding_box=(left=1031, bottom=452, right=1102, top=420, score=0.900500676761835))
# , (text=3%, confidence=0.00040896248538047075, bounding_box=(left=1245, bottom=452, right=1281, top=420, score=0.9067458673975521))
# , (text=1.ç26, confidence=0.0004082151281181723, bounding_box=(left=1483, bottom=452, right=1543, top=420, score=0.9030278520128592))
# , (text=*运输服务*客运服务费, confidence=0.000409622211009264, bounding_box=(left=31, bottom=451, right=272, top=421, score=0.8932533541509697))
# , (text=1, confidence=0.0004086058179382235, bounding_box=(left=809, bottom=446, right=823, top=426, score=0.8126227813107626))
# , (text=￥42.ç04, confidence=0.0004029205592814833, bounding_box=(left=1056, bottom=587, right=1143, top=556, score=0.868076281114058))
# , (text=￥1.ç26ç, confidence=0.00040521740447729826, bounding_box=(left=1461, bottom=587, right=1537, top=556, score=0.9016312285663599))
# , (text=计, confidence=0.0004101378726772964, bounding_box=(left=256, bottom=585, right=283, top=559, score=0.8955982338104929))
# , (text=合, confidence=0.00041010582935996354, bounding_box=(left=145, bottom=585, right=168, top=562, score=0.8082998196283977))
# , (text=出行日期, confidence=0.00041017637704499066, bounding_box=(left=513, bottom=620, right=616, top=584, score=0.8894929280346733))
# , (text=等级, confidence=0.00040987052489072084, bounding_box=(left=1267, bottom=620, right=1325, top=585, score=0.8456620449725265))
# , (text=出行人, confidence=0.00041014348971657455, bounding_box=(left=70, bottom=619, right=150, top=586, score=0.893267642138368))
# , (text=有效身份证件号, confidence=0.0004101790254935622, bounding_box=(left=239, bottom=619, right=412, top=586, score=0.8491815834996713))
# , (text=出发地, confidence=0.00040998379699885845, bounding_box=(left=762, bottom=619, right=843, top=586, score=0.9295449501110448))
# , (text=到达地, confidence=0.000410015054512769, bounding_box=(left=1047, bottom=619, right=1128, top=586, score=0.8919644558595287))
# , (text=交通工具类型, confidence=0.0004101662489119917, bounding_box=(left=1375, bottom=617, right=1524, top=588, score=0.8476022369852674))
# , (text=肆拾叁圆叁角, confidence=0.00041010897257365286, bounding_box=(left=420, bottom=798, right=569, top=765, score=0.8183270522223955))
# , (text=（小写）￥43.30, confidence=0.0004079292411915958, bounding_box=(left=1057, bottom=802, right=1243, top=765, score=0.8776343864964462))
# , (text=价税合计ç（大写）, confidence=0.0004077714402228594, bounding_box=(left=90, bottom=797, right=299, top=767, score=0.9016828199750498))
# , (text=各强, confidence=0.0004064732638653368, bounding_box=(left=36, bottom=927, right=70, top=845, score=0.7680051824985407))
# , (text=开票人：侯娇, confidence=0.00041006473475135863, bounding_box=(left=138, bottom=1027, right=298, top=998, score=0.8694359009197961))
# ]
# 2025-04-09 15:50:54,637 - myocr.extractor.chat_extractor - DEBUG - chat_extractor - extract_with_format - 19 - Extract infomation via OpanAI client with format:<class '__main__.InvoiceModel'> from OCR content:
# 发票）
# 电子发
# 严统发著
#
# 音
# 发票号码：24517000000216393366
# 旅客运输服务
# 州
# 咖
# 国家税务总局
# 开票日期：2024年10月19日
# 司
# 四
# 川
# 务
# 省税
# 1
#
# o
# 名称：北京邑邻科技有限公司
# 名称：成都滴滴优行科技有限公司
# 统一社会信用代码/纳税人识别号：91510100MA6B7L2R7L
# 统一社会信用代码/纳税人识别号：91110105MA01Q7QUXU
# 单价
# 数量
# 金额
# 税率ç/征收率
# 项目名称
# 税额
# 42.04
# 42.04
# 3%
# 1.ç26
# *运输服务*客运服务费
# 1
# ￥42.ç04
# ￥1.ç26ç
# 计
# 合
# 出行日期
# 等级
# 出行人
# 有效身份证件号
# 出发地
# 到达地
# 交通工具类型
# 肆拾叁圆叁角
# （小写）￥43.30
# 价税合计ç（大写）
# 各强
# 开票人：侯娇
# 2025-04-09 15:50:54,642 - openai._base_client - DEBUG - _base_client - _build_request - 453 - Request options: {'method': 'post', 'url': '/chat/completions', 'headers': {'X-Stainless-Helper-Method': 'beta.chat.completions.parse'}, 'files': None, 'post_parser': <function Completions.parse.<locals>.parser at 0x78ffc8489a80>, 'json_data': {'messages': [{'role': 'system', 'content': 'You are good at extracting information from the invoice, please extract corresponding information from the given texts recognized via OCR'}, {'role': 'user', 'content': '发票）\n电子发\n严统发著\n\n音\n发票号码：24517000000216393366\n旅客运输服务\n州\n咖\n国家税务总局\n开票日期：2024年10月19日\n司\n四\n川\n务\n省税\n1\n\no\n名称：北京邑邻科技有限公司\n名称：成都滴滴优行科技有限公司\n统一社会信用代码/纳税人识别号：91510100MA6B7L2R7L\n统一社会信用代码/纳税人识别号：91110105MA01Q7QUXU\n单价\n数量\n金额\n税率ç/征收率\n项目名称\n税额\n42.04\n42.04\n3%\n1.ç26\n*运输服务*客运服务费\n1\n￥42.ç04\n￥1.ç26ç\n计\n合\n出行日期\n等级\n出行人\n有效身份证件号\n出发地\n到达地\n交通工具类型\n肆拾叁圆叁角\n（小写）￥43.30\n价税合计ç（大写）\n各强\n开票人：侯娇'}], 'model': 'qwen2.5:14b', 'response_format': {'type': 'json_schema', 'json_schema': {'schema': {'$defs': {'InvoiceItem': {'properties': {'name': {'description': '发票中的项目名称', 'title': 'Name', 'type': 'string'}, 'price': {'description': '项目单价', 'title': 'Price', 'type': 'number'}, 'number': {'description': '项目数量', 'title': 'Number', 'type': 'string'}, 'tax': {'description': '项目税额，请转为两位小数表示', 'title': 'Tax', 'type': 'string'}}, 'required': ['name', 'price', 'number', 'tax'], 'title': 'InvoiceItem', 'type': 'object', 'additionalProperties': False}}, 'properties': {'invoiceNumber': {'description': '发票号码，一般在发票的又上角', 'title': 'Invoicenumber', 'type': 'string'}, 'invoiceDate': {'description': '发票日期，每张发票都有一个开票日期，一般在发票的右上角，请用这种格式展示 yyyy/MM/DD', 'title': 'Invoicedate', 'type': 'string'}, 'invoiceItems': {'description': '发票中的项目列表，这是发票中的主要内容，一般包含项目的名称，单价，数量，总价，税率，税额等，注意：这个字段是数组类型', 'items': {'$ref': '#/$defs/InvoiceItem'}, 'title': 'Invoiceitems', 'type': 'array'}, 'totalAmount': {'description': '发票的总金额', 'title': 'Totalamount', 'type': 'number'}}, 'required': ['invoiceNumber', 'invoiceDate', 'invoiceItems', 'totalAmount'], 'title': 'InvoiceModel', 'type': 'object', 'additionalProperties': False}, 'name': 'InvoiceModel', 'strict': True}}, 'stream': False}}
# 2025-04-09 15:50:54,643 - openai._base_client - DEBUG - _base_client - _request - 952 - Sending HTTP Request: POST http://192.168.0.70:11434/v1/chat/completions
# 2025-04-09 15:50:54,643 - httpcore.connection - DEBUG - _trace - trace - 47 - connect_tcp.started host='192.168.0.70' port=11434 local_address=None timeout=5.0 socket_options=None
# 2025-04-09 15:50:54,643 - httpcore.connection - DEBUG - _trace - trace - 47 - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x78ffc849f710>
# 2025-04-09 15:50:54,644 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_headers.started request=<Request [b'POST']>
# 2025-04-09 15:50:54,644 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_headers.complete
# 2025-04-09 15:50:54,644 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_body.started request=<Request [b'POST']>
# 2025-04-09 15:50:54,644 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_body.complete
# 2025-04-09 15:50:54,644 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-09 15:50:56,908 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json'), (b'Date', b'Wed, 09 Apr 2025 07:50:56 GMT'), (b'Content-Length', b'611')])
# 2025-04-09 15:50:56,908 - httpx - INFO - _client - _send_single_request - 1025 - HTTP Request: POST http://192.168.0.70:11434/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-04-09 15:50:56,909 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_body.started request=<Request [b'POST']>
# 2025-04-09 15:50:56,909 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_body.complete
# 2025-04-09 15:50:56,909 - httpcore.http11 - DEBUG - _trace - trace - 47 - response_closed.started
# 2025-04-09 15:50:56,910 - httpcore.http11 - DEBUG - _trace - trace - 47 - response_closed.complete
# 2025-04-09 15:50:56,910 - openai._base_client - DEBUG - _base_client - _request - 991 - HTTP Response: POST http://192.168.0.70:11434/v1/chat/completions "200 OK" Headers({'content-type': 'application/json', 'date': 'Wed, 09 Apr 2025 07:50:56 GMT', 'content-length': '611'})
# 2025-04-09 15:50:56,910 - openai._base_client - DEBUG - _base_client - _request - 999 - request_id: None
# InvoiceModel(invoiceNumber='24517000000216393366', invoiceDate='2024年10月19日', invoiceItems=[InvoiceItem(name='*运输服务*客运服务费', price=42.04, number='Yes', tax='After tax rate set at 3%')], totalAmount=43.3)
