# %%
from pydantic import BaseModel, Field
from myocr.pipelines.structured_output_pipeline import StructuredOutputOCRPipeline


class InvoiceItem(BaseModel):
    name:str = Field(
        description="发票中的项目名称"
    )
    price:float = Field(
        description="项目单价"
    )
    number:str = Field(
        description="项目数量"
    )
    tax:str = Field(
        description="项目税额，请转为两位小数表示"
    )

class InvoiceModel(BaseModel):
    invoiceNumber:str = Field(
        description="发票号码，一般在发票的又上角"
    )
    invoiceDate:str = Field(
        description="发票日期，每张发票都有一个开票日期，一般在发票的右上角，请用这种格式展示 yyyy/MM/DD"
    )
    invoiceItems: list[InvoiceItem] = Field(
        description="发票中的项目列表，这是发票中的主要内容，一般包含项目的名称，单价，数量，总价，税率，税额等，注意：这个字段是数组类型"
    )
    totalAmount:float = Field(
        description="发票的总金额"
    )


pipeline = StructuredOutputOCRPipeline("cuda:0", InvoiceModel)
pipeline("../../tests/images/invoice.png")
# Out:
# 2025-04-03 17:13:55,901 - matplotlib - DEBUG - __init__ - wrapper - 342 - matplotlib data path: /home/robby/miniconda3/envs/myocr/lib/python3.11/site-packages/matplotlib/mpl-data
# 2025-04-03 17:13:55,905 - matplotlib - DEBUG - __init__ - wrapper - 342 - CONFIGDIR=/home/robby/.config/matplotlib
# 2025-04-03 17:13:55,909 - matplotlib - DEBUG - __init__ - <module> - 1557 - interactive is False
# 2025-04-03 17:13:55,909 - matplotlib - DEBUG - __init__ - <module> - 1558 - platform is linux
# 2025-04-03 17:13:55,929 - matplotlib - DEBUG - __init__ - wrapper - 342 - CACHEDIR=/home/robby/.cache/matplotlib
# 2025-04-03 17:13:55,930 - matplotlib.font_manager - DEBUG - font_manager - _load_fontmanager - 1635 - Using fontManager instance from /home/robby/.cache/matplotlib/fontlist-v390.json
# 2025-04-03 17:13:56,089 - myocr.modeling.model - INFO - model - load - 126 - Onnx model /home/robby/.MyOCR/models/dbnet++.onnx loaded to cuda:0,
#                     input output info: {'inputs': {'x': {'shape': ['p2o.DynamicDimension.0', 3, 'p2o.DynamicDimension.1', 'p2o.DynamicDimension.2'], 'type': 'tensor(float)'}}, 'outputs': {'sigmoid_0.tmp_0': {'shape': ['p2o.DynamicDimension.3', 1, 'p2o.DynamicDimension.4', 'p2o.DynamicDimension.5'], 'type': 'tensor(float)'}}}
# 2025-04-03 17:13:56,112 - myocr.modeling.model - INFO - model - load - 126 - Onnx model /home/robby/.MyOCR/models/crnn_lite_lstm.onnx loaded to cuda:0,
#                     input output info: {'inputs': {'input': {'shape': ['batch_size', 3, 32, 'img_w'], 'type': 'tensor(float)'}}, 'outputs': {'out': {'shape': [64, 1, 5531], 'type': 'tensor(float)'}}}
# 2025-04-03 17:13:56,385 - myocr.predictors.text_detection_predictor - DEBUG - text_detection_predictor - convert_output - 85 - text detection output shape: (1056, 1568)
# 2025-04-03 17:13:56,502 - myocr.predictors.text_recognition_predictor - DEBUG - text_recognition_predictor - convert_output - 89 - text recognition output shape: (183, 51, 5531)
# 2025-04-03 17:13:56,590 - myocr.pipelines.structured_output_pipeline - DEBUG - structured_output_pipeline - __call__ - 46 - recognized texts is: [(text=,发票), confidence=0.920524001121521, bounding_box=(left=885, bottom=125, right=1024, top=56, score=0.8755382433622291))
# , (text=电子发, confidence=0.9229046106338501, bounding_box=(left=521, bottom=123, right=682, top=58, score=0.8887948973740383))
# , (text=，家, confidence=0.8328636288642883, bounding_box=(left=683, bottom=108, right=861, top=64, score=0.43799788377065085))
# , (text=理家, confidence=0.8596199750900269, bounding_box=(left=830, bottom=112, right=888, top=74, score=0.7139545332502436))
# , (text=，家, confidence=0.8243317604064941, bounding_box=(left=790, bottom=115, right=848, top=87, score=0.6088384004659527))
# , (text=发票号码:24517000000216393366, confidence=0.996468722820282, bounding_box=(left=1162, bottom=114, right=1523, top=87, score=0.8445811400752314))
# , (text=旅客运输服务, confidence=0.9971229434013367, bounding_box=(left=243, bottom=130, right=391, top=100, score=0.9379645352677781))
# , (text=体, confidence=0.8512541651725769, bounding_box=(left=693, bottom=127, right=716, top=106, score=0.7340345462163289))
# , (text=, confidence=0.8577954173088074, bounding_box=(left=862, bottom=127, right=888, top=107, score=0.697746460084562))
# , (text=-国家动起园, confidence=0.8814702033996582, bounding_box=(left=731, bottom=148, right=847, top=109, score=0.7248885206306009))
# , (text=开票日期: 2024年10月19日, confidence=0.9938358068466187, bounding_box=(left=1161, bottom=159, right=1448, top=132, score=0.8337870823970539))
# , (text=绕, confidence=0.8616328239440918, bounding_box=(left=839, bottom=174, right=866, top=146, score=0.7119205463297512))
# , (text=, confidence=0.862400233745575, bounding_box=(left=713, bottom=172, right=735, top=148, score=0.7912848262172757))
# , (text=, confidence=0.8996317982673645, bounding_box=(left=735, bottom=182, right=758, top=160, score=0.7831367289026578))
# , (text=务, confidence=0.8853294253349304, bounding_box=(left=818, bottom=184, right=844, top=160, score=0.7439178495438068))
# , (text=税, confidence=0.9375351667404175, bounding_box=(left=762, bottom=189, right=819, top=163, score=0.782881618823324))
# , (text=, confidence=0.7541452050209045, bounding_box=(left=810, bottom=179, right=823, top=168, score=0.7052404930194218))
# , (text=, confidence=0.7393132448196411, bounding_box=(left=790, bottom=381, right=828, top=227, score=0.7138049015923152))
# , (text=, confidence=0.6834532618522644, bounding_box=(left=36, bottom=377, right=71, top=228, score=0.7978249785861349))
# , (text=名称:北京邑邻科技有限公司, confidence=0.9960287809371948, bounding_box=(left=79, bottom=270, right=389, top=241, score=0.8433992134585773))
# , (text=名称:成都滴滴优行科技有限公司, confidence=0.991355836391449, bounding_box=(left=836, bottom=270, right=1194, top=241, score=0.8286933904921515))
# , (text=统一社会信用代码/纳税人识别号:91510100MA6B7L2R7L, confidence=0.9915181994438171, bounding_box=(left=834, bottom=352, right=1495, top=323, score=0.7485454590197844))
# , (text=统一社会信用代码/纳税人识别号:91110105MAO1Q7QUXU, confidence=0.9964374303817749, bounding_box=(left=77, bottom=353, right=740, top=324, score=0.7606884741301113))
# , (text=，我, confidence=0.831281840801239, bounding_box=(left=538, bottom=422, right=610, top=384, score=0.8672588260806336))
# , (text=教蚤, confidence=0.911845862865448, bounding_box=(left=782, bottom=419, right=849, top=385, score=0.8792654913189503))
# , (text=金额, confidence=0.8945201635360718, bounding_box=(left=1032, bottom=420, right=1102, top=386, score=0.9415918178797892))
# , (text=税率/征收率, confidence=0.9910358190536499, bounding_box=(left=1193, bottom=419, right=1332, top=387, score=0.8943826571818677))
# , (text=项目名称, confidence=0.943525493144989, bounding_box=(left=194, bottom=416, right=299, top=388, score=0.8273995642024692))
# , (text=税额, confidence=0.897193968296051, bounding_box=(left=1471, bottom=419, right=1541, top=388, score=0.9166263459749472))
# , (text=42.04, confidence=0.9296905994415283, bounding_box=(left=538, bottom=452, right=609, top=420, score=0.9202162409440064))
# , (text=42. 04, confidence=0.9440605044364929, bounding_box=(left=1031, bottom=452, right=1102, top=420, score=0.900500676761835))
# , (text=3, confidence=0.8366774916648865, bounding_box=(left=1245, bottom=452, right=1281, top=420, score=0.9067458673975521))
# , (text=1.26, confidence=0.9145547747612, bounding_box=(left=1483, bottom=452, right=1543, top=420, score=0.9030278520128592))
# , (text=*运输服务*客运服务费, confidence=0.9925357103347778, bounding_box=(left=31, bottom=451, right=272, top=421, score=0.8932533541509697))
# , (text=, confidence=0.832017719745636, bounding_box=(left=809, bottom=446, right=823, top=426, score=0.8126227813107626))
# , (text=望4&44, confidence=0.8004547357559204, bounding_box=(left=1056, bottom=587, right=1143, top=556, score=0.868076281114058))
# , (text=望26, confidence=0.7133480310440063, bounding_box=(left=1461, bottom=587, right=1537, top=556, score=0.9016312285663599))
# , (text=, confidence=0.8555834889411926, bounding_box=(left=256, bottom=585, right=283, top=559, score=0.8955982338104929))
# , (text=, confidence=0.8537132143974304, bounding_box=(left=145, bottom=585, right=168, top=562, score=0.8082998196283977))
# , (text=出企且题, confidence=0.9044092893600464, bounding_box=(left=513, bottom=620, right=616, top=584, score=0.8894929280346733))
# , (text=等级, confidence=0.8736286163330078, bounding_box=(left=1267, bottom=620, right=1325, top=585, score=0.8456620449725265))
# , (text=出, confidence=0.9106378555297852, bounding_box=(left=70, bottom=619, right=150, top=586, score=0.893267642138368))
# , (text=有效份证还件季, confidence=0.9701911807060242, bounding_box=(left=239, bottom=619, right=412, top=586, score=0.8491815834996713))
# , (text=出发地, confidence=0.898094654083252, bounding_box=(left=762, bottom=619, right=843, top=586, score=0.9295449501110448))
# , (text=刻达地, confidence=0.9132537841796875, bounding_box=(left=1047, bottom=619, right=1128, top=586, score=0.8919644558595287))
# , (text=交通工具类型, confidence=0.9761433601379395, bounding_box=(left=1375, bottom=617, right=1524, top=588, score=0.8476022369852674))
# , (text=肆拾叁圆叁角, confidence=0.9897419214248657, bounding_box=(left=420, bottom=798, right=569, top=765, score=0.8183270522223955))
# , (text=(  写) W48,30, confidence=0.955223023891449, bounding_box=(left=1057, bottom=802, right=1243, top=765, score=0.8776343864964462))
# , (text=价税合计 (大写), confidence=0.9935189485549927, bounding_box=(left=90, bottom=797, right=299, top=767, score=0.9016828199750498))
# , (text=, confidence=0.8220605254173279, bounding_box=(left=36, bottom=927, right=70, top=845, score=0.7680051824985407))
# , (text=开票人: 侯娇, confidence=0.9835608601570129, bounding_box=(left=138, bottom=1027, right=298, top=998, score=0.8694359009197961))
# ]
# 2025-04-03 17:13:56,590 - myocr.extractor.chat_extractor - DEBUG - chat_extractor - extract_with_format - 19 - Extract infomation via OpanAI client with format:<class '__main__.InvoiceModel'> from OCR content:
# ,发票)
# 电子发
# ，家
# 理家
# ，家
# 发票号码:24517000000216393366
# 旅客运输服务
# 体
#
# -国家动起园
# 开票日期: 2024年10月19日
# 绕
#
#
# 务
# 税
#
#
#
# 名称:北京邑邻科技有限公司
# 名称:成都滴滴优行科技有限公司
# 统一社会信用代码/纳税人识别号:91510100MA6B7L2R7L
# 统一社会信用代码/纳税人识别号:91110105MAO1Q7QUXU
# ，我
# 教蚤
# 金额
# 税率/征收率
# 项目名称
# 税额
# 42.04
# 42. 04
# 3
# 1.26
# *运输服务*客运服务费
#
# 望4&44
# 望26
#
#
# 出企且题
# 等级
# 出
# 有效份证还件季
# 出发地
# 刻达地
# 交通工具类型
# 肆拾叁圆叁角
# (  写) W48,30
# 价税合计 (大写)
#
# 开票人: 侯娇
# 2025-04-03 17:13:56,595 - openai._base_client - DEBUG - _base_client - _build_request - 453 - Request options: {'method': 'post', 'url': '/chat/completions', 'headers': {'X-Stainless-Helper-Method': 'beta.chat.completions.parse'}, 'files': None, 'post_parser': <function Completions.parse.<locals>.parser at 0x75d1942659e0>, 'json_data': {'messages': [{'role': 'system', 'content': 'You are good at extracting information from the invoice, please extract corresponding information from the given texts recognized via OCR'}, {'role': 'user', 'content': ',发票)\n电子发\n，家\n理家\n，家\n发票号码:24517000000216393366\n旅客运输服务\n体\n\n-国家动起园\n开票日期: 2024年10月19日\n绕\n\n\n务\n税\n\n\n\n名称:北京邑邻科技有限公司\n名称:成都滴滴优行科技有限公司\n统一社会信用代码/纳税人识别号:91510100MA6B7L2R7L\n统一社会信用代码/纳税人识别号:91110105MAO1Q7QUXU\n，我\n教蚤\n金额\n税率/征收率\n项目名称\n税额\n42.04\n42. 04\n3\n1.26\n*运输服务*客运服务费\n\n望4&44\n望26\n\n\n出企且题\n等级\n出\n有效份证还件季\n出发地\n刻达地\n交通工具类型\n肆拾叁圆叁角\n(  写) W48,30\n价税合计 (大写)\n\n开票人: 侯娇'}], 'model': 'qwen2.5:14b', 'response_format': {'type': 'json_schema', 'json_schema': {'schema': {'$defs': {'InvoiceItem': {'properties': {'name': {'description': '发票中的项目名称', 'title': 'Name', 'type': 'string'}, 'price': {'description': '项目单价', 'title': 'Price', 'type': 'number'}, 'number': {'description': '项目数量', 'title': 'Number', 'type': 'string'}, 'tax': {'description': '项目税额，请转为两位小数表示', 'title': 'Tax', 'type': 'string'}}, 'required': ['name', 'price', 'number', 'tax'], 'title': 'InvoiceItem', 'type': 'object', 'additionalProperties': False}}, 'properties': {'invoiceNumber': {'description': '发票号码，一般在发票的又上角', 'title': 'Invoicenumber', 'type': 'string'}, 'invoiceDate': {'description': '发票日期，每张发票都有一个开票日期，一般在发票的右上角，请用这种格式展示 yyyy/MM/DD', 'title': 'Invoicedate', 'type': 'string'}, 'invoiceItems': {'description': '发票中的项目列表，这是发票中的主要内容，一般包含项目的名称，单价，数量，总价，税率，税额等，注意：这个字段是数组类型', 'items': {'$ref': '#/$defs/InvoiceItem'}, 'title': 'Invoiceitems', 'type': 'array'}, 'totalAmount': {'description': '发票的总金额', 'title': 'Totalamount', 'type': 'number'}}, 'required': ['invoiceNumber', 'invoiceDate', 'invoiceItems', 'totalAmount'], 'title': 'InvoiceModel', 'type': 'object', 'additionalProperties': False}, 'name': 'InvoiceModel', 'strict': True}}, 'stream': False}}
# 2025-04-03 17:13:56,596 - openai._base_client - DEBUG - _base_client - _request - 952 - Sending HTTP Request: POST http://127.0.0.1:11434/v1/chat/completions
# 2025-04-03 17:13:56,596 - httpcore.connection - DEBUG - _trace - trace - 47 - connect_tcp.started host='127.0.0.1' port=11434 local_address=None timeout=5.0 socket_options=None
# 2025-04-03 17:13:56,597 - httpcore.connection - DEBUG - _trace - trace - 47 - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x75d19ae8c310>
# 2025-04-03 17:13:56,597 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_headers.started request=<Request [b'POST']>
# 2025-04-03 17:13:56,597 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_headers.complete
# 2025-04-03 17:13:56,597 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_body.started request=<Request [b'POST']>
# 2025-04-03 17:13:56,597 - httpcore.http11 - DEBUG - _trace - trace - 47 - send_request_body.complete
# 2025-04-03 17:13:56,598 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-03 17:14:01,525 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Content-Type', b'application/json'), (b'Date', b'Thu, 03 Apr 2025 09:14:01 GMT'), (b'Content-Length', b'1320')])
# 2025-04-03 17:14:01,526 - httpx - INFO - _client - _send_single_request - 1025 - HTTP Request: POST http://127.0.0.1:11434/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-04-03 17:14:01,527 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_body.started request=<Request [b'POST']>
# 2025-04-03 17:14:01,527 - httpcore.http11 - DEBUG - _trace - trace - 47 - receive_response_body.complete
# 2025-04-03 17:14:01,527 - httpcore.http11 - DEBUG - _trace - trace - 47 - response_closed.started
# 2025-04-03 17:14:01,527 - httpcore.http11 - DEBUG - _trace - trace - 47 - response_closed.complete
# 2025-04-03 17:14:01,528 - openai._base_client - DEBUG - _base_client - _request - 991 - HTTP Response: POST http://127.0.0.1:11434/v1/chat/completions "200 OK" Headers({'content-type': 'application/json', 'date': 'Thu, 03 Apr 2025 09:14:01 GMT', 'content-length': '1320'})
# 2025-04-03 17:14:01,528 - openai._base_client - DEBUG - _base_client - _request - 999 - request_id: None
# InvoiceModel(invoiceNumber='24517000000216393366', invoiceDate='2024年10月19日', invoiceItems=[InvoiceItem(name='*运输服务*客运服务费', price=42.04, number='', tax='How Many CNY - To Be Determined (TBD)未明确表明数量，可能是默认为1或者需进一步确认。但是根据发票常见形式推断，这里直接表示单价的情况下通常是购买或消费了一单位的服务，因此可以根据上下文理解为数量是1个单位，除非另有说明或记录中涉及具体交易量。这里的“42.04”通常指的是金额而非单独项目数量，故未显示明确的数量值可以视为默认存在隐含的合理解释：一单位服务费。对于精确数值，需要原始文档或进一步确认为佳。”(但根据上下文理解，默认表示1个单位的服务费即可满足大多数情况下需求)的税额是1.26元，税率3%。')], totalAmount=43.3)
