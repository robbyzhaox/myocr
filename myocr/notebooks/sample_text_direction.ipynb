# %%
import time

import torch
from PIL import Image,ImageDraw
from myocr.config import MODEL_PATH
from myocr.modeling.model import ModelZoo
from myocr.predictors.text_direction_predictor import TextDirectionParamConverter
from myocr.predictors.text_detection_predictor import TextDetectionParamConverter
from myocr.predictors.text_recognition_predictor import TextRecognitionParamConverter


dec = ModelZoo.load_model("onnx", MODEL_PATH+"dbnet++.onnx", "cuda:0" if torch.cuda.is_available() else "cpu")
model = ModelZoo.load_model("onnx", MODEL_PATH+"cls.onnx", "cuda:0" if torch.cuda.is_available() else "cpu")
rec_model = ModelZoo.load_model("onnx", MODEL_PATH+"rec.onnx", "cuda:0" if torch.cuda.is_available() else "cpu")

orig_image = Image.open("../../tests/images/test_ocr.png").convert("RGB")

start_time = time.time()
dec_predictor = dec.predictor(TextDetectionParamConverter(dec.device))
detected = dec_predictor.predict(orig_image)
if not detected:
    print("Nothing detected")
else:
    p = model.predictor(TextDirectionParamConverter())
    rec = p.predict(detected)
    p_rec = rec_model.predictor(TextRecognitionParamConverter())
    result = p_rec.predict(rec)
    print(result)
    
draw = ImageDraw.Draw(orig_image)
for box in detected.bounding_boxes: # type: ignore
    print(box)
    draw.polygon(
        [(box.left, box.bottom), (box.left, box.top), (box.right, box.top), (box.right, box.bottom)],
        outline="green",
        width=2,
    )

display(orig_image)
# Out:
# 2025-04-21 18:17:41,592 - matplotlib - DEBUG - __init__ - wrapper - 342 - matplotlib data path: /home/robby/miniconda3/envs/myocr/lib/python3.11/site-packages/matplotlib/mpl-data
# 2025-04-21 18:17:41,596 - matplotlib - DEBUG - __init__ - wrapper - 342 - CONFIGDIR=/home/robby/.config/matplotlib
# 2025-04-21 18:17:41,600 - matplotlib - DEBUG - __init__ - <module> - 1557 - interactive is False
# 2025-04-21 18:17:41,600 - matplotlib - DEBUG - __init__ - <module> - 1558 - platform is linux
# 2025-04-21 18:17:41,620 - matplotlib - DEBUG - __init__ - wrapper - 342 - CACHEDIR=/home/robby/.cache/matplotlib
# 2025-04-21 18:17:41,622 - matplotlib.font_manager - DEBUG - font_manager - _load_fontmanager - 1635 - Using fontManager instance from /home/robby/.cache/matplotlib/fontlist-v390.json
# 2025-04-21 18:17:41,790 - myocr.modeling.model - INFO - model - load - 127 - Onnx model /home/robby/.MyOCR/models/dbnet++.onnx loaded to cuda:0,
#                     input output info: {'inputs': {'x': {'shape': ['p2o.DynamicDimension.0', 3, 'p2o.DynamicDimension.1', 'p2o.DynamicDimension.2'], 'type': 'tensor(float)'}}, 'outputs': {'sigmoid_0.tmp_0': {'shape': ['p2o.DynamicDimension.3', 1, 'p2o.DynamicDimension.4', 'p2o.DynamicDimension.5'], 'type': 'tensor(float)'}}}
# 2025-04-21 18:17:41,804 - myocr.modeling.model - INFO - model - load - 127 - Onnx model /home/robby/.MyOCR/models/cls.onnx loaded to cuda:0,
#                     input output info: {'inputs': {'x': {'shape': ['p2o.DynamicDimension.0', 3, 'p2o.DynamicDimension.1', 'p2o.DynamicDimension.2'], 'type': 'tensor(float)'}}, 'outputs': {'softmax_0.tmp_0': {'shape': ['p2o.DynamicDimension.3', 2], 'type': 'tensor(float)'}}}
# 2025-04-21 18:17:41,843 - myocr.modeling.model - INFO - model - load - 127 - Onnx model /home/robby/.MyOCR/models/rec.onnx loaded to cuda:0,
#                     input output info: {'inputs': {'x': {'shape': ['p2o.DynamicDimension.0', 3, 48, 'p2o.DynamicDimension.1'], 'type': 'tensor(float)'}}, 'outputs': {'softmax_11.tmp_0': {'shape': ['p2o.DynamicDimension.2', 'p2o.DynamicDimension.3', 6625], 'type': 'tensor(float)'}}}
# 2025-04-21 18:17:42,045 - myocr.predictors.text_detection_predictor - DEBUG - text_detection_predictor - convert_output - 87 - text detection output shape: (96, 800)
# 2025-04-21 18:17:42,105 - myocr.predictors.text_recognition_predictor - DEBUG - text_recognition_predictor - convert_output - 105 - text recognition output shape: (8, 15, 6625)
# [(text=地图, confidence=0.00041019555646926165, bounding_box=(left=249, bottom=71, right=309, top=26, angle=(0, np.float32(0.9967452)), score=0.8962185092372039))
# , (text=贴吧, confidence=0.0004101622907910496, bounding_box=(left=347, bottom=71, right=412, top=27, angle=(0, np.float32(0.99999857)), score=0.9004358919985566))
# , (text=视频, confidence=0.00041013737791217864, bounding_box=(left=448, bottom=71, right=513, top=27, angle=(0, np.float32(0.99988127)), score=0.8991658086086805))
# , (text=文库, confidence=0.0004101597878616303, bounding_box=(left=747, bottom=71, right=800, top=27, angle=(0, np.float32(0.9999856)), score=0.9433527915250688))
# , (text=新闻, confidence=0.0004101782978978008, bounding_box=(left=13, bottom=72, right=78, top=28, angle=(0, np.float32(0.99999774)), score=0.9553980316274833))
# , (text=图片, confidence=0.0004101844388060272, bounding_box=(left=549, bottom=72, right=612, top=28, angle=(0, np.float32(0.9999962)), score=0.9264097460187399))
# , (text=朝区, confidence=0.0003991046396549791, bounding_box=(left=649, bottom=72, right=713, top=28, angle=(180, np.float32(0.7808571)), score=0.8812482421885736))
# , (text=hao123, confidence=0.0004071233270224184, bounding_box=(left=115, bottom=70, right=212, top=31, angle=(0, np.float32(1.0)), score=0.8919633823452574))
# ]
# (left=249, bottom=71, right=309, top=26, angle=(0, np.float32(0.9967452)), score=0.8962185092372039)
# (left=347, bottom=71, right=412, top=27, angle=(0, np.float32(0.99999857)), score=0.9004358919985566)
# (left=448, bottom=71, right=513, top=27, angle=(0, np.float32(0.99988127)), score=0.8991658086086805)
# (left=747, bottom=71, right=800, top=27, angle=(0, np.float32(0.9999856)), score=0.9433527915250688)
# (left=13, bottom=72, right=78, top=28, angle=(0, np.float32(0.99999774)), score=0.9553980316274833)
# (left=549, bottom=72, right=612, top=28, angle=(0, np.float32(0.9999962)), score=0.9264097460187399)
# (left=649, bottom=72, right=713, top=28, angle=(180, np.float32(0.7808571)), score=0.8812482421885736)
# (left=115, bottom=70, right=212, top=31, angle=(0, np.float32(1.0)), score=0.8919633823452574)
# <PIL.Image.Image image mode=RGB size=828x124>
